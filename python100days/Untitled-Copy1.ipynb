# %%
import numpy as np
import pandas as pd
import matplotlib


#this line prepares IPython for working with matplotlib
# %matplotlib inline  

# this actually imports matplotlib
import matplotlib.pyplot as plt  

x = np.linspace(0, 10, 30)  #array of 30 points from 0 to 10
y = np.sin(x)
z = y + np.random.normal(size=30) * .2
plt.plot(x, y, 'ro-', label='A sine wave')
plt.plot(x, z, 'b-', label='Noisy sine')
plt.legend(loc = 'lower right')
plt.xlabel("X axis")
plt.ylabel("Y axis")
# Out:
# Text(0, 0.5, 'Y axis')

# %%
print(matplotlib.get_backend())
# Out:
# module://ipykernel.pylab.backend_inline

# %%
eye_mon_data = pd.read_csv("eye_data_nrz.txt", sep=' ', header=None, nrows=97)
eye_mon_phase_range=16
vert_size_side = 48
plt = matplotlib.pyplot
eye_mon_fig=plt.figure()
x=numpy.arange(-eye_mon_phase_range-1, eye_mon_phase_range+1)*0.0232      # Phase
y=numpy.arange(-vert_size_side-1, vert_size_side+1)*extent/vert_size_side   # Margin
c=matplotlib.pyplot.pcolor(x, y, eye_mon_data/-16, cmap='jet', vmin=-8, vmax=0, figure=eye_mon_fig)
eye_mon_fig.suptitle('Eye Monitor NRZ')
ber_axis=eye_mon_fig.add_axes([0.9, 0.1, 0.02, 0.8])
eye_mon_fig.colorbar(mappable=c, cax=ber_axis)
eye_mon_fig.show()

# %%
import pandas as pd
import matplotlib 
import matplotlib.pyplot as plt  

eye_mon_data = pd.read_csv("l26_nrz.txt", sep=' ', header=None, nrows=97)
extent=300
eye_mon_phase_range=16
vert_size_side = 48
plt = matplotlib.pyplot
eye_mon_fig=plt.figure()
x=numpy.arange(-eye_mon_phase_range-1, eye_mon_phase_range+1)*0.0232      # Phase
y=numpy.arange(-vert_size_side-1, vert_size_side+1)*extent/vert_size_side   # Margin
c=matplotlib.pyplot.pcolor(x, y, eye_mon_data/-16, cmap='jet', vmin=-8, vmax=0, figure=eye_mon_fig)
eye_mon_fig.suptitle('Eye Monitor NRZ')
ber_axis=eye_mon_fig.add_axes([0.9, 0.1, 0.02, 0.8])
eye_mon_fig.colorbar(mappable=c, cax=ber_axis)

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt  


eye_mon_data = pd.read_csv("eye_data_nrz.txt", sep=' ', header=None, nrows=97)
eye_mon_data1 = pd.read_csv("l26_nrz.txt", sep=' ', header=None, nrows=97)
eye_mon_phase_range=16
vert_size_side = 48

fig = plt.figure(1)
ax1= plt.subplot(121)

x=numpy.arange(-eye_mon_phase_range-1, eye_mon_phase_range+1)*0.0232      # Phase
y=numpy.arange(-vert_size_side-1, vert_size_side+1)*extent/vert_size_side   # Margin
plt.pcolor(x, y, eye_mon_data/-16, cmap='jet', vmin=-8, vmax=0)

ber_axis=fig.add_axes([0.9, 0.1, 0.02, 0.8])
fig.colorbar(mappable=c, cax=ber_axis)


plt.subplot(122)
plt.pcolor(x, y, eye_mon_data1/-16, cmap='jet', vmin=-8, vmax=0)

# %%
import numpy as np
import matplotlib.pyplot as plt

def fig(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure(1)
# 等同于 plt.subplot(2, 1，1)
plt.subplot(211)
plt.plot(t1, fig(t1), 'bo', t2, fig(t2), 'k')

# 等同于 plt.subplot(2, 1，2)
plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()
